# %% [markdown]
# # **Solving Complex Equations**

# %%
# import the necessary libraries
import numpy as np

# %%
# define the cofficent matrix of complex numbers.
A_commplex = np.array([[1 + 1j, 2 + 2j], [3 + 3j, 4 + 4j]])
print(A_commplex)
# Out:
# [[1.+1.j 2.+2.j]
#  [3.+3.j 4.+4.j]]

# %%
# define the constant matrix B iwth complex numbers.
B_compelx = np.array([5 + 5j, 6 + 6j])
print(B_compelx)
# Out:
# [5.+5.j 6.+6.j]

# %%
# solve the system of complex equation for X.
X_compelx = np.linalg.solve(A, B)
print(X_compelx)
# Out:
# [-4. +0.j  4.5+0.j]
